# %% [markdown]
# # **SENDY LOGISTICS CHALLENGE**

# %% [markdown]
# ## **DATA PREPROCESSING**

# %% [markdown]
# ## Import Libraries

# %%
#import all the important libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Loading the necessary libraries for visualization and computation.
#
# *   Numpy :
# *   Matplotlib.pyplot:
# *   Pandas:
# *   Seaborn:

# %% [markdown]
# ## Import Dataset

# %% [markdown]
# ### Import the Training, Test, VariableDefinitions and RiderId DataSet

# %%
dictionary = pd.read_csv('VariableDefinitions.csv')
dictionary
# Out:
#                                      Order No  \
# 0                                     User Id
# 1                                Vehicle Type
# 2                               Platform Type
# 3                        Personal or Business
# 4                    Placement - Day of Month
# 5                Placement - Weekday (Mo = 1)
# 6                            Placement - Time
# 7                 Confirmation - Day of Month
# 8             Confirmation - Weekday (Mo = 1)
# 9                         Confirmation - Time
# 10           Arrival at Pickup - Day of Month
# 11       Arrival at Pickup - Weekday (Mo = 1)
# 12                   Arrival at Pickup - Time
# 13                      Pickup - Day of Month
# 14                  Pickup - Weekday (Mo = 1)
# 15                              Pickup - Time
# 16      Arrival at Destination - Day of Month
# 17  Arrival at Destination - Weekday (Mo = 1)
# 18              Arrival at Destination - Time
# 19                              Distance (KM)
# 20                                Temperature
# 21               Precipitation in millimeters
# 22                                 Pickup Lat
# 23                                Pickup Long
# 24                            Destination Lat
# 25                           Destination Long
# 26                                   Rider Id
# 27                Time from Pickup to Arrival
# 28                                        NaN
# 29                              Rider Metrics
# 30                                   Rider Id
# 31                               No_Of_Orders
# 32                                        Age
# 33                             Average_Rating
# 34                              No_of_Ratings
#
#                   Unique number identifying the order
# 0   Unique number identifying the customer on a pl...
# 1   For this competition limited to bikes, however...
# 2   Platform used to place the order, there are 4 ...
# 3                                       Customer type
# 4                   Placement - Day of Month i.e 1-31
# 5                    Placement - Weekday (Monday = 1)
# 6   Placement - Time - Time of day the order was p...
# 7                Confirmation - Day of Month i.e 1-31
# 8                 Confirmation - Weekday (Monday = 1)
# 9   Confirmation - Time - Time of day the order wa...
# 10          Arrival at Pickup - Day of Month i.e 1-31
# 11           Arrival at Pickup - Weekday (Monday = 1)
# 12  Time of day the the rider arrived at the locat...
# 13                     Pickup - Day of Month i.e 1-31
# 14                      Pickup - Weekday (Monday = 1)
# 15  Pickup - Time - Time of day the the rider pick...
# 16        Arrival at Delivery - Day of Month i.e 1-31
# 17         Arrival at Delivery - Weekday (Monday = 1)
# 18  Arrival at Delivery Time - Time of day the rid...
# 19            The distance from Pickup to Destination
# 20  Temperature at the time of order placement in ...
# 21   Precipitation at the time of order placement ...
# 22                       Latitude of pick up location
# 23                      Longitude of pick up location
# 24                      Latitude of delivery location
# 25                     Longitude of delivery location
# 26             ID of the Rider who accepted the order
# 27  Time in seconds between 'Pickup' and 'Arrival ...
# 28                                                NaN
# 29                                                NaN
# 30  Unique number identifying the rider (same as i...
# 31           Number of Orders the rider has delivered
# 32  Number of days since the rider delivered the f...
# 33                        Average rating of the rider
# 34   Number of ratings the rider has received. Rat...

# %% [markdown]
# Importing the Variable Defination to get more information about the items/values stored in each variable

# %%
#import training dataset and observe the results
train_set = pd.read_csv('Train.csv')
print(len(train_set.columns))
print(train_set.columns)
# Out:
# 29
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival'],
#       dtype='object')

# %% [markdown]
# Loading the Train Dataset, Inspecting the total count of the dataset variables,and observing the names of each variable

# %%
test_set = pd.read_csv('Test.csv')
print(len(test_set.columns))
print(test_set.columns)
# Out:
# 25
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Distance (KM)', 'Temperature', 'Precipitation in millimeters',
#        'Pickup Lat', 'Pickup Long', 'Destination Lat', 'Destination Long',
#        'Rider Id'],
#       dtype='object')

# %% [markdown]
# Loading the Test Dataset, Inspecting the total count of the dataset variables,and observing the names of each variable.
#
# We can conclude the following after observing the variable count and variable name for both the Train and Test dataset:
#
#
# *   The Train dataset has 29 varibale, wherease the Test dataset has only 24 variable.
# *   Assuming our test dataset is unseen data it is expected to have a difference of n-1(n is the number of columns).

# %%
rider_info = pd.read_csv('Riders.csv')
print(len(rider_info.columns))
print(rider_info.columns)
# Out:
# 5
# Index(['Rider Id', 'No_Of_Orders', 'Age', 'Average_Rating', 'No_of_Ratings'], dtype='object')

# %% [markdown]
# Loading the Rider Info Dataset,inspect the total count of the variable,and obeserving the names of each variable.
# Total Count:5

# %% [markdown]
# Loading the Rider Info dataset

# %%
for column in train_set.columns:
    if column not in test_set.columns:
        print(column)
# Out:
# Arrival at Destination - Day of Month
# Arrival at Destination - Weekday (Mo = 1)
# Arrival at Destination - Time
# Time from Pickup to Arrival

# %% [markdown]
# We already know that the total count of the Train and Test dataset does not match, It will be appropiate to observe the variables contributing to this incosistency in the Train and Test Dataset. Frrom the Above we can observe the following:
#
#
# *   There are 3 Variable in the Train dataframe which are not in the Train Dataset,namely Arrival at Destination - Day of Month,Arrival at Destination - Weekday (Mo = 1),Arrival at Destination - Time,Time from Pickup to Arrival
# *   It would make sense to have one variable missing in the Train dataset because its unseen, which means it won't have the Idependent Variable.
# *   The Purpose of this task is to prepare the model for unseen data, with that in mind, it will be important that the trained dataset and the testing dataset have matching variable.
# *   We would need to perform Data Cleaning to make sure our dataset matches correctly.

# %%
train_set.drop(['Arrival at Destination - Day of Month', 'Arrival at Destination - Weekday (Mo = 1)', 'Arrival at Destination - Time'], axis=1, inplace=True)
print(len(train_set.columns))
print(train_set.columns)
# Out:
# 26
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Distance (KM)', 'Temperature', 'Precipitation in millimeters',
#        'Pickup Lat', 'Pickup Long', 'Destination Lat', 'Destination Long',
#        'Rider Id', 'Time from Pickup to Arrival'],
#       dtype='object')

# %% [markdown]
# Cleaning Our data Data would mean getting rid of variables that are in onne dataset but not the other.
#
# We dropped 3 Variable in the Train Dataset namely:
# Arrival at Destination - Day of Month
# Arrival at Destination - Weekday (Mo = 1)
# Arrival at Destination - Time;The reason why we drop these variable in our train More conceptually, when training your model, it learns a set of parameters with a shape that matches the dimensionality of your featureset (the number of columns in your training set). If your test set is missing one or more of the columns that were in your training set, when your model attempts to make predictions using the coefficients it's learned, it will suddenly be surprised to find that there are no values in the test row to multiply by those coefficients that it learned from the columns that were originally in the training set (but now are missing from the test set). This is the point at which your model would most likely throw an error.
# We kept One Variable which is Time from Pickup to Arrival, This variable is kept beacuse it is Our Dependent Variable.

# %%
train_set = pd.merge(train_set, rider_info, on='Rider Id', how= 'left')

test_set = pd.merge(test_set, rider_info, on='Rider Id', how= 'left')

# %% [markdown]
# There are more variables that included in the Rider Info that we can use to improve our model prediction accuracy, One of the methods for improving Models is to add more variables.
#
# To achieve this we have to add the variables to both our Train and Test dataset.

# %%
column_titles = [col for col in train_set.columns if col!= 'Time from Pickup to Arrival'] + ['Time from Pickup to Arrival']
train_set= train_set.reindex(columns=column_titles)

# %% [markdown]
# In pandas when you merge two dataframe together the .merge() method has a parametre 'How' to specify which side do you want the dataframes to me merged. This will cause the new dataframe to have additional columns on the side
# Since it is always advisable to keep our dependent variable on the last column.

# %%
train_set.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup Lat  Pickup Long  \
# 0                                5  ...  -1.317755    36.830370
# 1                                5  ...  -1.351453    36.899315
# 2                                2  ...  -1.308284    36.843419
# 3                                5  ...  -1.281301    36.832396
# 4                                1  ...  -1.266597    36.792118
#
#    Destination Lat Destination Long      Rider Id  No_Of_Orders   Age  \
# 0        -1.300406        36.829741  Rider_Id_432          1637  1309
# 1        -1.295004        36.814358  Rider_Id_856           396   339
# 2        -1.300921        36.828195  Rider_Id_155          1023   242
# 3        -1.257147        36.795063  Rider_Id_855           886   283
# 4        -1.295041        36.809817  Rider_Id_770          2311   872
#
#    Average_Rating  No_of_Ratings  Time from Pickup to Arrival
# 0            13.8            549                          745
# 1            13.6             69                         1993
# 2            12.5            114                          455
# 3            14.5            113                         1341
# 4            14.1            533                         1214
#
# [5 rows x 30 columns]

# %%
test_set.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1  Order_No_12736  User_Id_3647         Bike              3
# 2    Order_No_768  User_Id_2154         Bike              3
# 3  Order_No_15332  User_Id_2910         Bike              3
# 4  Order_No_21373  User_Id_1205         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Business                        17
# 2             Business                        27
# 3             Business                        17
# 4             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# 2                             4      11:08:14 AM                           27
# 3                             1       1:51:35 PM                           17
# 4                             2      11:30:28 AM                           11
#
#    Confirmation - Weekday (Mo = 1)  ... Precipitation in millimeters  \
# 0                                3  ...                          NaN
# 1                                5  ...                          NaN
# 2                                4  ...                          NaN
# 3                                1  ...                          NaN
# 4                                2  ...                          NaN
#
#    Pickup Lat  Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0   -1.333275    36.870815       -1.305249         36.822390  Rider_Id_192
# 1   -1.272639    36.794723       -1.277007         36.823907  Rider_Id_868
# 2   -1.290894    36.822971       -1.276574         36.851365   Rider_Id_26
# 3   -1.290503    36.809646       -1.303382         36.790658  Rider_Id_685
# 4   -1.281081    36.814423       -1.266467         36.792161  Rider_Id_858
#
#   No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0          439  1511            13.3            171
# 1          488   273            14.4             45
# 2          833   460            13.1             67
# 3          487   560            13.7             44
# 4         4761  1120            14.1           1010
#
# [5 rows x 29 columns]

# %%
train_set['Temperature'] = train_set['Temperature'].fillna(train_set['Temperature'].mean())
test_set['Temperature'] = test_set['Temperature'].fillna(test_set['Temperature'].mean())

train_set['Precipitation in millimeters'] = train_set['Precipitation in millimeters'].fillna(0)
test_set['Precipitation in millimeters'] = test_set['Precipitation in millimeters'].fillna(0)

# %%
train_set.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1)  ... Pickup Lat  Pickup Long  \
# 0                                5  ...  -1.317755    36.830370
# 1                                5  ...  -1.351453    36.899315
# 2                                2  ...  -1.308284    36.843419
# 3                                5  ...  -1.281301    36.832396
# 4                                1  ...  -1.266597    36.792118
#
#    Destination Lat Destination Long      Rider Id  No_Of_Orders   Age  \
# 0        -1.300406        36.829741  Rider_Id_432          1637  1309
# 1        -1.295004        36.814358  Rider_Id_856           396   339
# 2        -1.300921        36.828195  Rider_Id_155          1023   242
# 3        -1.257147        36.795063  Rider_Id_855           886   283
# 4        -1.295041        36.809817  Rider_Id_770          2311   872
#
#    Average_Rating  No_of_Ratings  Time from Pickup to Arrival
# 0            13.8            549                          745
# 1            13.6             69                         1993
# 2            12.5            114                          455
# 3            14.5            113                         1341
# 4            14.1            533                         1214
#
# [5 rows x 30 columns]

# %%
test_set.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1  Order_No_12736  User_Id_3647         Bike              3
# 2    Order_No_768  User_Id_2154         Bike              3
# 3  Order_No_15332  User_Id_2910         Bike              3
# 4  Order_No_21373  User_Id_1205         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Business                        17
# 2             Business                        27
# 3             Business                        17
# 4             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# 2                             4      11:08:14 AM                           27
# 3                             1       1:51:35 PM                           17
# 4                             2      11:30:28 AM                           11
#
#    Confirmation - Weekday (Mo = 1)  ... Precipitation in millimeters  \
# 0                                3  ...                          0.0
# 1                                5  ...                          0.0
# 2                                4  ...                          0.0
# 3                                1  ...                          0.0
# 4                                2  ...                          0.0
#
#    Pickup Lat  Pickup Long Destination Lat  Destination Long      Rider Id  \
# 0   -1.333275    36.870815       -1.305249         36.822390  Rider_Id_192
# 1   -1.272639    36.794723       -1.277007         36.823907  Rider_Id_868
# 2   -1.290894    36.822971       -1.276574         36.851365   Rider_Id_26
# 3   -1.290503    36.809646       -1.303382         36.790658  Rider_Id_685
# 4   -1.281081    36.814423       -1.266467         36.792161  Rider_Id_858
#
#   No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0          439  1511            13.3            171
# 1          488   273            14.4             45
# 2          833   460            13.1             67
# 3          487   560            13.7             44
# 4         4761  1120            14.1           1010
#
# [5 rows x 29 columns]

# %%
test_copy = test_set.copy()

# %%
train_set.drop(['User Id', 'Vehicle Type','Order No', 'Rider Id' ],axis=1, inplace=True)

test_set.drop(['User Id', 'Vehicle Type','Order No', 'Rider Id' ],axis=1, inplace=True)

# %%
train_set.head()
# Out:
#    Platform Type Personal or Business  Placement - Day of Month  \
# 0              3             Business                         9
# 1              3             Personal                        12
# 2              3             Business                        30
# 3              3             Business                        15
# 4              1             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# 2                             2      12:39:25 PM                           30
# 3                             5       9:25:34 AM                           15
# 4                             1       9:55:18 AM                           13
#
#    Confirmation - Weekday (Mo = 1) Confirmation - Time  \
# 0                                5          9:40:10 AM
# 1                                5         11:23:21 AM
# 2                                2         12:42:44 PM
# 3                                5          9:26:05 AM
# 4                                1          9:56:18 AM
#
#    Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# 0                                 9                                     5
# 1                                12                                     5
# 2                                30                                     2
# 3                                15                                     5
# 4                                13                                     1
#
#    ... Precipitation in millimeters  Pickup Lat  Pickup Long Destination Lat  \
# 0  ...                          0.0   -1.317755    36.830370       -1.300406
# 1  ...                          0.0   -1.351453    36.899315       -1.295004
# 2  ...                          0.0   -1.308284    36.843419       -1.300921
# 3  ...                          0.0   -1.281301    36.832396       -1.257147
# 4  ...                          0.0   -1.266597    36.792118       -1.295041
#
#    Destination Long  No_Of_Orders   Age  Average_Rating  No_of_Ratings  \
# 0         36.829741          1637  1309            13.8            549
# 1         36.814358           396   339            13.6             69
# 2         36.828195          1023   242            12.5            114
# 3         36.795063           886   283            14.5            113
# 4         36.809817          2311   872            14.1            533
#
#    Time from Pickup to Arrival
# 0                          745
# 1                         1993
# 2                          455
# 3                         1341
# 4                         1214
#
# [5 rows x 26 columns]

# %%
test_set.head()
# Out:
#    Platform Type Personal or Business  Placement - Day of Month  \
# 0              3             Business                        27
# 1              3             Business                        17
# 2              3             Business                        27
# 3              3             Business                        17
# 4              3             Business                        11
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             3       4:44:10 PM                           27
# 1                             5      12:57:35 PM                           17
# 2                             4      11:08:14 AM                           27
# 3                             1       1:51:35 PM                           17
# 4                             2      11:30:28 AM                           11
#
#    Confirmation - Weekday (Mo = 1) Confirmation - Time  \
# 0                                3          4:44:29 PM
# 1                                5         12:59:17 PM
# 2                                4         11:25:05 AM
# 3                                1          1:53:27 PM
# 4                                2         11:34:45 AM
#
#    Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# 0                                27                                     3
# 1                                17                                     5
# 2                                27                                     4
# 3                                17                                     1
# 4                                11                                     2
#
#    ... Temperature  Precipitation in millimeters  Pickup Lat Pickup Long  \
# 0  ...    23.24612                           0.0   -1.333275   36.870815
# 1  ...    23.24612                           0.0   -1.272639   36.794723
# 2  ...    22.80000                           0.0   -1.290894   36.822971
# 3  ...    24.50000                           0.0   -1.290503   36.809646
# 4  ...    24.40000                           0.0   -1.281081   36.814423
#
#    Destination Lat  Destination Long  No_Of_Orders   Age  Average_Rating  \
# 0        -1.305249         36.822390           439  1511            13.3
# 1        -1.277007         36.823907           488   273            14.4
# 2        -1.276574         36.851365           833   460            13.1
# 3        -1.303382         36.790658           487   560            13.7
# 4        -1.266467         36.792161          4761  1120            14.1
#
#    No_of_Ratings
# 0            171
# 1             45
# 2             67
# 3             44
# 4           1010
#
# [5 rows x 25 columns]

# %%
train_set.describe().T
# Out:
#                                         count         mean          std  \
# Platform Type                         21201.0     2.752182     0.625178
# Placement - Day of Month              21201.0    15.653696     8.798916
# Placement - Weekday (Mo = 1)          21201.0     3.240083     1.567295
# Confirmation - Day of Month           21201.0    15.653837     8.798886
# Confirmation - Weekday (Mo = 1)       21201.0     3.240225     1.567228
# Arrival at Pickup - Day of Month      21201.0    15.653837     8.798886
# Arrival at Pickup - Weekday (Mo = 1)  21201.0     3.240225     1.567228
# Pickup - Day of Month                 21201.0    15.653837     8.798886
# Pickup - Weekday (Mo = 1)             21201.0     3.240225     1.567228
# Distance (KM)                         21201.0     9.506533     5.668963
# Temperature                           21201.0    23.258889     3.222006
# Precipitation in millimeters          21201.0     0.205839     3.029194
# Pickup Lat                            21201.0    -1.281470     0.030507
# Pickup Long                           21201.0    36.811264     0.037473
# Destination Lat                       21201.0    -1.282581     0.034824
# Destination Long                      21201.0    36.811220     0.044721
# No_Of_Orders                          21201.0  1692.423706  1574.308302
# Age                                   21201.0   984.742842   646.652835
# Average_Rating                        21201.0    13.882520     0.916071
# No_of_Ratings                         21201.0   341.067119   402.867746
# Time from Pickup to Arrival           21201.0  1556.920947   987.270788
#
#                                             min         25%          50%  \
# Platform Type                          1.000000    3.000000     3.000000
# Placement - Day of Month               1.000000    8.000000    15.000000
# Placement - Weekday (Mo = 1)           1.000000    2.000000     3.000000
# Confirmation - Day of Month            1.000000    8.000000    15.000000
# Confirmation - Weekday (Mo = 1)        1.000000    2.000000     3.000000
# Arrival at Pickup - Day of Month       1.000000    8.000000    15.000000
# Arrival at Pickup - Weekday (Mo = 1)   1.000000    2.000000     3.000000
# Pickup - Day of Month                  1.000000    8.000000    15.000000
# Pickup - Weekday (Mo = 1)              1.000000    2.000000     3.000000
# Distance (KM)                          1.000000    5.000000     8.000000
# Temperature                           11.200000   21.400000    23.258889
# Precipitation in millimeters           0.000000    0.000000     0.000000
# Pickup Lat                            -1.438302   -1.300921    -1.279395
# Pickup Long                           36.653621   36.784605    36.807040
# Destination Lat                       -1.430298   -1.301201    -1.284382
# Destination Long                      36.606594   36.785661    36.808002
# No_Of_Orders                           2.000000  557.000000  1212.000000
# Age                                   96.000000  495.000000   872.000000
# Average_Rating                         0.000000   13.600000    14.000000
# No_of_Ratings                          0.000000   61.000000   161.000000
# Time from Pickup to Arrival            1.000000  882.000000  1369.000000
#
#                                               75%          max
# Platform Type                            3.000000     4.000000
# Placement - Day of Month                23.000000    31.000000
# Placement - Weekday (Mo = 1)             5.000000     7.000000
# Confirmation - Day of Month             23.000000    31.000000
# Confirmation - Weekday (Mo = 1)          5.000000     7.000000
# Arrival at Pickup - Day of Month        23.000000    31.000000
# Arrival at Pickup - Weekday (Mo = 1)     5.000000     7.000000
# Pickup - Day of Month                   23.000000    31.000000
# Pickup - Weekday (Mo = 1)                5.000000     7.000000
# Distance (KM)                           13.000000    49.000000
# Temperature                             25.300000    32.100000
# Precipitation in millimeters             0.000000    99.100000
# Pickup Lat                              -1.257147    -1.147170
# Pickup Long                             36.829741    36.991046
# Destination Lat                         -1.261177    -1.030225
# Destination Long                        36.829477    37.016779
# No_Of_Orders                          2311.000000  9756.000000
# Age                                   1236.000000  3764.000000
# Average_Rating                          14.300000    15.200000
# No_of_Ratings                          495.000000  2298.000000
# Time from Pickup to Arrival           2040.000000  7883.000000

# %%
train_set.corr()
# Out:
#                                       Platform Type  Placement - Day of Month  \
# Platform Type                              1.000000                  0.012764
# Placement - Day of Month                   0.012764                  1.000000
# Placement - Weekday (Mo = 1)              -0.058038                  0.026148
# Confirmation - Day of Month                0.012770                  0.999998
# Confirmation - Weekday (Mo = 1)           -0.058005                  0.026122
# Arrival at Pickup - Day of Month           0.012770                  0.999998
# Arrival at Pickup - Weekday (Mo = 1)      -0.058005                  0.026122
# Pickup - Day of Month                      0.012770                  0.999998
# Pickup - Weekday (Mo = 1)                 -0.058005                  0.026122
# Distance (KM)                              0.005528                 -0.007585
# Temperature                                0.211494                  0.011605
# Precipitation in millimeters              -0.011401                 -0.044518
# Pickup Lat                                -0.002742                 -0.004929
# Pickup Long                                0.021327                 -0.005453
# Destination Lat                            0.006319                  0.007541
# Destination Long                           0.043924                  0.002077
# No_Of_Orders                               0.024060                  0.008096
# Age                                       -0.074029                 -0.000107
# Average_Rating                            -0.014664                  0.012790
# No_of_Ratings                             -0.031886                 -0.001709
# Time from Pickup to Arrival               -0.003827                 -0.014710
#
#                                       Placement - Weekday (Mo = 1)  \
# Platform Type                                            -0.058038
# Placement - Day of Month                                  0.026148
# Placement - Weekday (Mo = 1)                              1.000000
# Confirmation - Day of Month                               0.026132
# Confirmation - Weekday (Mo = 1)                           0.999952
# Arrival at Pickup - Day of Month                          0.026132
# Arrival at Pickup - Weekday (Mo = 1)                      0.999952
# Pickup - Day of Month                                     0.026132
# Pickup - Weekday (Mo = 1)                                 0.999952
# Distance (KM)                                             0.003582
# Temperature                                               0.027703
# Precipitation in millimeters                             -0.024879
# Pickup Lat                                               -0.000918
# Pickup Long                                               0.011008
# Destination Lat                                          -0.004299
# Destination Long                                         -0.000875
# No_Of_Orders                                             -0.024226
# Age                                                      -0.015475
# Average_Rating                                           -0.006834
# No_of_Ratings                                            -0.025747
# Time from Pickup to Arrival                               0.009693
#
#                                       Confirmation - Day of Month  \
# Platform Type                                            0.012770
# Placement - Day of Month                                 0.999998
# Placement - Weekday (Mo = 1)                             0.026132
# Confirmation - Day of Month                              1.000000
# Confirmation - Weekday (Mo = 1)                          0.026123
# Arrival at Pickup - Day of Month                         1.000000
# Arrival at Pickup - Weekday (Mo = 1)                     0.026123
# Pickup - Day of Month                                    1.000000
# Pickup - Weekday (Mo = 1)                                0.026123
# Distance (KM)                                           -0.007587
# Temperature                                              0.011606
# Precipitation in millimeters                            -0.044520
# Pickup Lat                                              -0.004923
# Pickup Long                                             -0.005448
# Destination Lat                                          0.007550
# Destination Long                                         0.002073
# No_Of_Orders                                             0.008099
# Age                                                     -0.000114
# Average_Rating                                           0.012796
# No_of_Ratings                                           -0.001712
# Time from Pickup to Arrival                             -0.014701
#
#                                       Confirmation - Weekday (Mo = 1)  \
# Platform Type                                               -0.058005
# Placement - Day of Month                                     0.026122
# Placement - Weekday (Mo = 1)                                 0.999952
# Confirmation - Day of Month                                  0.026123
# Confirmation - Weekday (Mo = 1)                              1.000000
# Arrival at Pickup - Day of Month                             0.026123
# Arrival at Pickup - Weekday (Mo = 1)                         1.000000
# Pickup - Day of Month                                        0.026123
# Pickup - Weekday (Mo = 1)                                    1.000000
# Distance (KM)                                                0.003574
# Temperature                                                  0.027712
# Precipitation in millimeters                                -0.024886
# Pickup Lat                                                  -0.000883
# Pickup Long                                                  0.011036
# Destination Lat                                             -0.004251
# Destination Long                                            -0.000900
# No_Of_Orders                                                -0.024205
# Age                                                         -0.015514
# Average_Rating                                              -0.006803
# No_of_Ratings                                               -0.025768
# Time from Pickup to Arrival                                  0.009744
#
#                                       Arrival at Pickup - Day of Month  \
# Platform Type                                                 0.012770
# Placement - Day of Month                                      0.999998
# Placement - Weekday (Mo = 1)                                  0.026132
# Confirmation - Day of Month                                   1.000000
# Confirmation - Weekday (Mo = 1)                               0.026123
# Arrival at Pickup - Day of Month                              1.000000
# Arrival at Pickup - Weekday (Mo = 1)                          0.026123
# Pickup - Day of Month                                         1.000000
# Pickup - Weekday (Mo = 1)                                     0.026123
# Distance (KM)                                                -0.007587
# Temperature                                                   0.011606
# Precipitation in millimeters                                 -0.044520
# Pickup Lat                                                   -0.004923
# Pickup Long                                                  -0.005448
# Destination Lat                                               0.007550
# Destination Long                                              0.002073
# No_Of_Orders                                                  0.008099
# Age                                                          -0.000114
# Average_Rating                                                0.012796
# No_of_Ratings                                                -0.001712
# Time from Pickup to Arrival                                  -0.014701
#
#                                       Arrival at Pickup - Weekday (Mo = 1)  \
# Platform Type                                                    -0.058005
# Placement - Day of Month                                          0.026122
# Placement - Weekday (Mo = 1)                                      0.999952
# Confirmation - Day of Month                                       0.026123
# Confirmation - Weekday (Mo = 1)                                   1.000000
# Arrival at Pickup - Day of Month                                  0.026123
# Arrival at Pickup - Weekday (Mo = 1)                              1.000000
# Pickup - Day of Month                                             0.026123
# Pickup - Weekday (Mo = 1)                                         1.000000
# Distance (KM)                                                     0.003574
# Temperature                                                       0.027712
# Precipitation in millimeters                                     -0.024886
# Pickup Lat                                                       -0.000883
# Pickup Long                                                       0.011036
# Destination Lat                                                  -0.004251
# Destination Long                                                 -0.000900
# No_Of_Orders                                                     -0.024205
# Age                                                              -0.015514
# Average_Rating                                                   -0.006803
# No_of_Ratings                                                    -0.025768
# Time from Pickup to Arrival                                       0.009744
#
#                                       Pickup - Day of Month  \
# Platform Type                                      0.012770
# Placement - Day of Month                           0.999998
# Placement - Weekday (Mo = 1)                       0.026132
# Confirmation - Day of Month                        1.000000
# Confirmation - Weekday (Mo = 1)                    0.026123
# Arrival at Pickup - Day of Month                   1.000000
# Arrival at Pickup - Weekday (Mo = 1)               0.026123
# Pickup - Day of Month                              1.000000
# Pickup - Weekday (Mo = 1)                          0.026123
# Distance (KM)                                     -0.007587
# Temperature                                        0.011606
# Precipitation in millimeters                      -0.044520
# Pickup Lat                                        -0.004923
# Pickup Long                                       -0.005448
# Destination Lat                                    0.007550
# Destination Long                                   0.002073
# No_Of_Orders                                       0.008099
# Age                                               -0.000114
# Average_Rating                                     0.012796
# No_of_Ratings                                     -0.001712
# Time from Pickup to Arrival                       -0.014701
#
#                                       Pickup - Weekday (Mo = 1)  \
# Platform Type                                         -0.058005
# Placement - Day of Month                               0.026122
# Placement - Weekday (Mo = 1)                           0.999952
# Confirmation - Day of Month                            0.026123
# Confirmation - Weekday (Mo = 1)                        1.000000
# Arrival at Pickup - Day of Month                       0.026123
# Arrival at Pickup - Weekday (Mo = 1)                   1.000000
# Pickup - Day of Month                                  0.026123
# Pickup - Weekday (Mo = 1)                              1.000000
# Distance (KM)                                          0.003574
# Temperature                                            0.027712
# Precipitation in millimeters                          -0.024886
# Pickup Lat                                            -0.000883
# Pickup Long                                            0.011036
# Destination Lat                                       -0.004251
# Destination Long                                      -0.000900
# No_Of_Orders                                          -0.024205
# Age                                                   -0.015514
# Average_Rating                                        -0.006803
# No_of_Ratings                                         -0.025768
# Time from Pickup to Arrival                            0.009744
#
#                                       Distance (KM)  ...  \
# Platform Type                              0.005528  ...
# Placement - Day of Month                  -0.007585  ...
# Placement - Weekday (Mo = 1)               0.003582  ...
# Confirmation - Day of Month               -0.007587  ...
# Confirmation - Weekday (Mo = 1)            0.003574  ...
# Arrival at Pickup - Day of Month          -0.007587  ...
# Arrival at Pickup - Weekday (Mo = 1)       0.003574  ...
# Pickup - Day of Month                     -0.007587  ...
# Pickup - Weekday (Mo = 1)                  0.003574  ...
# Distance (KM)                              1.000000  ...
# Temperature                               -0.002090  ...
# Precipitation in millimeters              -0.001761  ...
# Pickup Lat                                -0.124338  ...
# Pickup Long                                0.178537  ...
# Destination Lat                           -0.079366  ...
# Destination Long                           0.135397  ...
# No_Of_Orders                               0.037186  ...
# Age                                        0.036239  ...
# Average_Rating                            -0.008200  ...
# No_of_Ratings                              0.051806  ...
# Time from Pickup to Arrival                0.580608  ...
#
#                                       Precipitation in millimeters  \
# Platform Type                                            -0.011401
# Placement - Day of Month                                 -0.044518
# Placement - Weekday (Mo = 1)                             -0.024879
# Confirmation - Day of Month                              -0.044520
# Confirmation - Weekday (Mo = 1)                          -0.024886
# Arrival at Pickup - Day of Month                         -0.044520
# Arrival at Pickup - Weekday (Mo = 1)                     -0.024886
# Pickup - Day of Month                                    -0.044520
# Pickup - Weekday (Mo = 1)                                -0.024886
# Distance (KM)                                            -0.001761
# Temperature                                              -0.116503
# Precipitation in millimeters                              1.000000
# Pickup Lat                                               -0.005395
# Pickup Long                                              -0.007141
# Destination Lat                                          -0.001703
# Destination Long                                          0.006729
# No_Of_Orders                                              0.012714
# Age                                                       0.012079
# Average_Rating                                           -0.000432
# No_of_Ratings                                             0.014191
# Time from Pickup to Arrival                               0.005495
#
#                                       Pickup Lat  Pickup Long  \
# Platform Type                          -0.002742     0.021327
# Placement - Day of Month               -0.004929    -0.005453
# Placement - Weekday (Mo = 1)           -0.000918     0.011008
# Confirmation - Day of Month            -0.004923    -0.005448
# Confirmation - Weekday (Mo = 1)        -0.000883     0.011036
# Arrival at Pickup - Day of Month       -0.004923    -0.005448
# Arrival at Pickup - Weekday (Mo = 1)   -0.000883     0.011036
# Pickup - Day of Month                  -0.004923    -0.005448
# Pickup - Weekday (Mo = 1)              -0.000883     0.011036
# Distance (KM)                          -0.124338     0.178537
# Temperature                             0.015950     0.007824
# Precipitation in millimeters           -0.005395    -0.007141
# Pickup Lat                              1.000000    -0.147629
# Pickup Long                            -0.147629     1.000000
# Destination Lat                         0.114975     0.014992
# Destination Long                        0.051399     0.082803
# No_Of_Orders                           -0.018190     0.011274
# Age                                     0.002481    -0.001656
# Average_Rating                          0.043610    -0.001885
# No_of_Ratings                           0.019458     0.002221
# Time from Pickup to Arrival            -0.053823     0.060285
#
#                                       Destination Lat  Destination Long  \
# Platform Type                                0.006319          0.043924
# Placement - Day of Month                     0.007541          0.002077
# Placement - Weekday (Mo = 1)                -0.004299         -0.000875
# Confirmation - Day of Month                  0.007550          0.002073
# Confirmation - Weekday (Mo = 1)             -0.004251         -0.000900
# Arrival at Pickup - Day of Month             0.007550          0.002073
# Arrival at Pickup - Weekday (Mo = 1)        -0.004251         -0.000900
# Pickup - Day of Month                        0.007550          0.002073
# Pickup - Weekday (Mo = 1)                   -0.004251         -0.000900
# Distance (KM)                               -0.079366          0.135397
# Temperature                                  0.009236          0.023421
# Precipitation in millimeters                -0.001703          0.006729
# Pickup Lat                                   0.114975          0.051399
# Pickup Long                                  0.014992          0.082803
# Destination Lat                              1.000000          0.046767
# Destination Long                             0.046767          1.000000
# No_Of_Orders                                -0.001135         -0.013809
# Age                                          0.009552         -0.018235
# Average_Rating                               0.030488          0.002017
# No_of_Ratings                                0.015015         -0.002748
# Time from Pickup to Arrival                 -0.061872          0.070425
#
#                                       No_Of_Orders       Age  Average_Rating  \
# Platform Type                             0.024060 -0.074029       -0.014664
# Placement - Day of Month                  0.008096 -0.000107        0.012790
# Placement - Weekday (Mo = 1)             -0.024226 -0.015475       -0.006834
# Confirmation - Day of Month               0.008099 -0.000114        0.012796
# Confirmation - Weekday (Mo = 1)          -0.024205 -0.015514       -0.006803
# Arrival at Pickup - Day of Month          0.008099 -0.000114        0.012796
# Arrival at Pickup - Weekday (Mo = 1)     -0.024205 -0.015514       -0.006803
# Pickup - Day of Month                     0.008099 -0.000114        0.012796
# Pickup - Weekday (Mo = 1)                -0.024205 -0.015514       -0.006803
# Distance (KM)                             0.037186  0.036239       -0.008200
# Temperature                               0.030102 -0.037470       -0.024769
# Precipitation in millimeters              0.012714  0.012079       -0.000432
# Pickup Lat                               -0.018190  0.002481        0.043610
# Pickup Long                               0.011274 -0.001656       -0.001885
# Destination Lat                          -0.001135  0.009552        0.030488
# Destination Long                         -0.013809 -0.018235        0.002017
# No_Of_Orders                              1.000000  0.669036        0.051375
# Age                                       0.669036  1.000000       -0.014348
# Average_Rating                            0.051375 -0.014348        1.000000
# No_of_Ratings                             0.857918  0.651090        0.073856
# Time from Pickup to Arrival              -0.041608 -0.007969       -0.042559
#
#                                       No_of_Ratings  \
# Platform Type                             -0.031886
# Placement - Day of Month                  -0.001709
# Placement - Weekday (Mo = 1)              -0.025747
# Confirmation - Day of Month               -0.001712
# Confirmation - Weekday (Mo = 1)           -0.025768
# Arrival at Pickup - Day of Month          -0.001712
# Arrival at Pickup - Weekday (Mo = 1)      -0.025768
# Pickup - Day of Month                     -0.001712
# Pickup - Weekday (Mo = 1)                 -0.025768
# Distance (KM)                              0.051806
# Temperature                               -0.007461
# Precipitation in millimeters               0.014191
# Pickup Lat                                 0.019458
# Pickup Long                                0.002221
# Destination Lat                            0.015015
# Destination Long                          -0.002748
# No_Of_Orders                               0.857918
# Age                                        0.651090
# Average_Rating                             0.073856
# No_of_Ratings                              1.000000
# Time from Pickup to Arrival                0.005609
#
#                                       Time from Pickup to Arrival
# Platform Type                                           -0.003827
# Placement - Day of Month                                -0.014710
# Placement - Weekday (Mo = 1)                             0.009693
# Confirmation - Day of Month                             -0.014701
# Confirmation - Weekday (Mo = 1)                          0.009744
# Arrival at Pickup - Day of Month                        -0.014701
# Arrival at Pickup - Weekday (Mo = 1)                     0.009744
# Pickup - Day of Month                                   -0.014701
# Pickup - Weekday (Mo = 1)                                0.009744
# Distance (KM)                                            0.580608
# Temperature                                              0.005772
# Precipitation in millimeters                             0.005495
# Pickup Lat                                              -0.053823
# Pickup Long                                              0.060285
# Destination Lat                                         -0.061872
# Destination Long                                         0.070425
# No_Of_Orders                                            -0.041608
# Age                                                     -0.007969
# Average_Rating                                          -0.042559
# No_of_Ratings                                            0.005609
# Time from Pickup to Arrival                              1.000000
#
# [21 rows x 21 columns]

# %%
corr = train_set.corr()
fig, axes = plt.subplots(figsize=(10, 10))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    ax = axes
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %%
fig, axs = plt.subplots(5,5, figsize=(20,15),)
fig.subplots_adjust(hspace = 0.5, wspace=.2)
axs = axs.ravel()

for index, column in enumerate(train_set.columns):
    if train_set[column].dtype != 'object':
      axs[index-1].set_title("{} vs. Time".format(column),fontsize=16)
      axs[index-1].scatter(x=train_set[column],y=train_set['Time from Pickup to Arrival'],color='blue',edgecolor='k')

fig.tight_layout(pad=1)

# %%
geo_spatial = train_set[['Pickup Lat', 'Pickup Long', 'Destination Lat', 'Destination Long']]
BBox1 = (train_set['Pickup Long'].min(),train_set['Pickup Long'].max(),      
         train_set['Pickup Lat'].min(), train_set['Pickup Lat'].max())
BBox2 = (train_set['Destination Long'].min(), train_set['Destination Long'].max(),      
        train_set['Destination Lat'].min(), train_set['Destination Lat'].max())    
print(BBox1)
print(BBox2)
# Out:
# (36.653621, 36.99104620000001, -1.4383017, -1.1471704)
# (36.6065939, 37.016779299999996, -1.4302983, -1.0302254000000002)

# %%
#ruh_m = plt.imread(r"C:\Users\Lesedi\Downloads\Maps\Pickup.osm")
#fig, ax = plt.subplots(figsize = (8,7))
#ax.scatter(train_set['Pickup Long'], train_set['Pickup Lat'], zorder=1, alpha= 0.2, c='b', s=10)
#ax.set_title('Plotting Spatial Data on Riyadh Map')
#ax.set_xlim(BBox1[0],BBox1[1])
#ax.set_ylim(BBox1[2],BBox1[3])
#ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %%
#BBox2 = ((train_set['Destination Long'].min(), train_set['Destination Long'].max(),      
#        train_set['Destination Lat'].min(), train_set['Destination Lat'].max())    
#BBox1
#print(BBox2)             
#geo_spatial.head()

# %%
sns.distplot(train_set['Time from Pickup to Arrival'])

# %% [markdown]
# ## Preproccessing the Datasets

# %%
def convert_to_24hrs(column):
    column = pd.to_datetime(column, format='%I:%M:%S %p').dt.strftime("%H:%M:%S")
    return column

# %%
train_set['Confirmation - Time'] = pd.to_timedelta(convert_to_24hrs(train_set['Confirmation - Time'] ))
train_set['Placement - Time'] = pd.to_timedelta(convert_to_24hrs(train_set['Placement - Time'] ))
train_set['Arrival at Pickup - Time'] =  pd.to_timedelta(convert_to_24hrs(train_set['Arrival at Pickup - Time'] ))
train_set['Pickup - Time'] =  pd.to_timedelta(convert_to_24hrs(train_set['Pickup - Time'] ))

test_set['Confirmation - Time'] = pd.to_timedelta(convert_to_24hrs(test_set['Confirmation - Time'] ))
test_set['Placement - Time'] = pd.to_timedelta(convert_to_24hrs(test_set['Placement - Time'] ))
test_set['Arrival at Pickup - Time'] =  pd.to_timedelta(convert_to_24hrs(test_set['Arrival at Pickup - Time'] ))
test_set['Pickup - Time'] =  pd.to_timedelta(convert_to_24hrs(test_set['Pickup - Time'] ))

# %%
train_set['Time from Confirmation to placement'] = train_set['Confirmation - Time']- train_set['Placement - Time']
train_set['Waiting Time'] = train_set['Pickup - Time']- train_set['Arrival at Pickup - Time']

test_set['Time from Confirmation to placement'] = test_set['Confirmation - Time']- test_set['Placement - Time']
test_set['Waiting Time'] = test_set['Pickup - Time']- test_set['Arrival at Pickup - Time']

# %%
train_set['Time from Confirmation to placement'] = train_set['Time from Confirmation to placement'] / np.timedelta64(1, 's')
train_set['Waiting Time'] = train_set['Waiting Time'] / np.timedelta64(1, 's')

test_set['Time from Confirmation to placement'] = test_set['Time from Confirmation to placement'] / np.timedelta64(1, 's')
test_set['Waiting Time'] = test_set['Waiting Time'] / np.timedelta64(1, 's')

# %%
train_set.drop(['Confirmation - Time','Placement - Time' ,'Pickup - Time','Arrival at Pickup - Time'],
             axis=1, inplace=True)

test_set.drop(['Confirmation - Time','Placement - Time' ,'Pickup - Time','Arrival at Pickup - Time'],
             axis=1, inplace=True)

# %%
column_titles = [col for col in train_set.columns if col!= 'Time from Pickup to Arrival'] + ['Time from Pickup to Arrival']
train_set= train_set.reindex(columns=column_titles)

# %%
train_set.drop([ 'Placement - Day of Month', 'Placement - Weekday (Mo = 1)', 'Arrival at Pickup - Day of Month', 'Arrival at Pickup - Weekday (Mo = 1)', 'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'No_of_Ratings', 'Age'],
             axis=1, inplace=True)

test_set.drop([ 'Placement - Day of Month', 'Placement - Weekday (Mo = 1)', 'Arrival at Pickup - Day of Month', 'Arrival at Pickup - Weekday (Mo = 1)', 'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'No_of_Ratings', 'Age'],
             axis=1, inplace=True)

# %%
def find_true_distance(Pick_up_lat, Pick_up_long, Destination_lat, Destination_long):
    from math import sin, cos, sqrt, atan2, radians

    # approximate radius of earth in km
    R = 6373.0

    Pick_up_lat = Pick_up_lat.apply(lambda x: radians(x))
    Pick_up_long = Pick_up_long.apply(lambda x: radians(x))
    Destination_lat = Destination_lat.apply(lambda x: radians(x))
    Destination_long = Destination_long.apply(lambda x: radians(x))

    dlon = Destination_long - Pick_up_long
    dlat = Destination_lat - Pick_up_lat 

    a = dlat.apply(lambda x: sin( x/ 2)**2) + Pick_up_lat.apply(lambda x: cos(x)) * Destination_lat.apply(lambda x: cos(x)) * dlon.apply(lambda x : sin(x / 2)**2)
    c = 2 * a.apply(lambda x: atan2(sqrt(x), sqrt(1 - x)))

    return round(R * c)

# %%
train_set['True Distance'] = find_true_distance(train_set['Pickup Lat'], train_set['Pickup Long'], train_set['Destination Lat'], train_set['Destination Long'])

test_set['True Distance'] = find_true_distance(test_set['Pickup Lat'], test_set['Pickup Long'], test_set['Destination Lat'], test_set['Destination Long'])

# %%
train_set[['True Distance', 'Distance (KM)']]
# Out:
#        True Distance  Distance (KM)
# 0                2.0              4
# 1               11.0             16
# 2                2.0              3
# 3                5.0              9
# 4                4.0              9
# ...              ...            ...
# 21196            2.0              3
# 21197            4.0              7
# 21198           11.0             20
# 21199            9.0             13
# 21200            9.0             12
#
# [21201 rows x 2 columns]

# %%
train_set.drop(['Pickup Lat', 'Pickup Long', 'Destination Lat', 'Destination Long'],
             axis=1, inplace=True)

# %%
test_set.drop(['Pickup Lat', 'Pickup Long', 'Destination Lat', 'Destination Long'],
             axis=1, inplace=True)

# %%
column_titles = [col for col in train_set.columns if col!= 'Time from Pickup to Arrival'] + ['Time from Pickup to Arrival']
train_set= train_set.reindex(columns=column_titles)

# %%
train_set.head()
# Out:
#    Platform Type Personal or Business  Confirmation - Day of Month  \
# 0              3             Business                            9
# 1              3             Personal                           12
# 2              3             Business                           30
# 3              3             Business                           15
# 4              1             Personal                           13
#
#    Confirmation - Weekday (Mo = 1)  Distance (KM)  Temperature  \
# 0                                5              4    20.400000
# 1                                5             16    26.400000
# 2                                2              3    23.258889
# 3                                5              9    19.200000
# 4                                1              9    15.400000
#
#    Precipitation in millimeters  No_Of_Orders  Average_Rating  \
# 0                           0.0          1637            13.8
# 1                           0.0           396            13.6
# 2                           0.0          1023            12.5
# 3                           0.0           886            14.5
# 4                           0.0          2311            14.1
#
#    Time from Confirmation to placement  Waiting Time  True Distance  \
# 0                                264.0        1363.0            2.0
# 1                                425.0         227.0           11.0
# 2                                199.0         209.0            2.0
# 3                                 31.0         310.0            5.0
# 4                                 60.0          90.0            4.0
#
#    Time from Pickup to Arrival
# 0                          745
# 1                         1993
# 2                          455
# 3                         1341
# 4                         1214

# %%
test_set.head()
# Out:
#    Platform Type Personal or Business  Confirmation - Day of Month  \
# 0              3             Business                           27
# 1              3             Business                           17
# 2              3             Business                           27
# 3              3             Business                           17
# 4              3             Business                           11
#
#    Confirmation - Weekday (Mo = 1)  Distance (KM)  Temperature  \
# 0                                3              8     23.24612
# 1                                5              5     23.24612
# 2                                4              5     22.80000
# 3                                1              5     24.50000
# 4                                2              6     24.40000
#
#    Precipitation in millimeters  No_Of_Orders  Average_Rating  \
# 0                           0.0           439            13.3
# 1                           0.0           488            14.4
# 2                           0.0           833            13.1
# 3                           0.0           487            13.7
# 4                           0.0          4761            14.1
#
#    Time from Confirmation to placement  Waiting Time  True Distance
# 0                                 19.0         823.0            6.0
# 1                                102.0         310.0            3.0
# 2                               1011.0        1474.0            4.0
# 3                                112.0         851.0            3.0
# 4                                257.0         525.0            3.0

# %%
corr = train_set.corr()
fig, axes = plt.subplots(figsize=(10, 10))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    ax = axes
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=90,
    horizontalalignment='right'
);

# %%
fig, axs = plt.subplots(1,2, figsize=(20,15),)
fig.subplots_adjust(hspace = 0.5, wspace=.2)
axs = axs.ravel()

axs[0].set_title("{} vs. Time".format('True Distance'),fontsize=16)
axs[0].scatter(x=train_set['True Distance'],y=train_set['Time from Pickup to Arrival'],color='blue',edgecolor='k')

axs[1].set_title("{} vs. Time".format('Distance (KM)'),fontsize=16)
axs[1].scatter(x=train_set['Distance (KM)'],y=train_set['Time from Pickup to Arrival'],color='blue',edgecolor='k')

fig.tight_layout(pad=1)

# %%
train_set.describe().T
# Out:
#                                        count         mean          std  \
# Platform Type                        21201.0     2.752182     0.625178
# Confirmation - Day of Month          21201.0    15.653837     8.798886
# Confirmation - Weekday (Mo = 1)      21201.0     3.240225     1.567228
# Distance (KM)                        21201.0     9.506533     5.668963
# Temperature                          21201.0    23.258889     3.222006
# Precipitation in millimeters         21201.0     0.205839     3.029194
# No_Of_Orders                         21201.0  1692.423706  1574.308302
# Average_Rating                       21201.0    13.882520     0.916071
# Time from Confirmation to placement  21201.0   433.231121  1025.742011
# Waiting Time                         21201.0   744.186406   761.216606
# True Distance                        21201.0     6.527098     4.459179
# Time from Pickup to Arrival          21201.0  1556.920947   987.270788
#
#                                         min    25%          50%     75%  \
# Platform Type                           1.0    3.0     3.000000     3.0
# Confirmation - Day of Month             1.0    8.0    15.000000    23.0
# Confirmation - Weekday (Mo = 1)         1.0    2.0     3.000000     5.0
# Distance (KM)                           1.0    5.0     8.000000    13.0
# Temperature                            11.2   21.4    23.258889    25.3
# Precipitation in millimeters            0.0    0.0     0.000000     0.0
# No_Of_Orders                            2.0  557.0  1212.000000  2311.0
# Average_Rating                          0.0   13.6    14.000000    14.3
# Time from Confirmation to placement -4664.0   27.0    69.000000   289.0
# Waiting Time                           60.0  263.0   491.000000   929.0
# True Distance                           0.0    3.0     5.000000     9.0
# Time from Pickup to Arrival             1.0  882.0  1369.000000  2040.0
#
#                                          max
# Platform Type                            4.0
# Confirmation - Day of Month             31.0
# Confirmation - Weekday (Mo = 1)          7.0
# Distance (KM)                           49.0
# Temperature                             32.1
# Precipitation in millimeters            99.1
# No_Of_Orders                          9756.0
# Average_Rating                          15.2
# Time from Confirmation to placement  14480.0
# Waiting Time                          5985.0
# True Distance                           37.0
# Time from Pickup to Arrival           7883.0

# %%
fig, axs = plt.subplots(4,4, figsize=(20,15),)
fig.subplots_adjust(hspace = 0.5, wspace=.2)
axs = axs.ravel()

for index, column in enumerate(train_set.columns):
      axs[index-1].set_title("{} vs. Time".format(column),fontsize=16)
      axs[index-1].scatter(x=train_set[column],y=train_set['Time from Pickup to Arrival'],color='blue',edgecolor='k')

fig.tight_layout(pad=1)

# %%
fig, axs = plt.subplots(1,2, figsize=(20,15),)
fig.subplots_adjust(hspace = 0.5, wspace=.2)
axs = axs.ravel()

axs[0].set_title("{} vs. Time".format('True Distance'),fontsize=16)
axs[0].scatter(x=train_set['Time from Confirmation to placement'],y=train_set['Time from Pickup to Arrival'],color='blue',edgecolor='k')

axs[1].set_title("{} vs. Time".format('Distance (KM)'),fontsize=16)
axs[1].scatter(x=train_set['Waiting Time'],y=train_set['Time from Pickup to Arrival'],color='blue',edgecolor='k')

fig.tight_layout(pad=1)

# %%
y_train = train_set.iloc[:,-1].values
y_train.reshape(len(y_train),1)
# Out:
# array([[ 745],
#        [1993],
#        [ 455],
#        ...,
#        [2953],
#        [1380],
#        [2128]], dtype=int64)

# %%
X_train = train_set.iloc[:,:-1].values
X_train
# Out:
# array([[3, 'Business', 9, ..., 264.0, 1363.0, 2.0],
#        [3, 'Personal', 12, ..., 425.0, 227.0, 11.0],
#        [3, 'Business', 30, ..., 199.0, 209.0, 2.0],
#        ...,
#        [3, 'Business', 7, ..., 53.0, 1235.0, 11.0],
#        [1, 'Personal', 4, ..., 14.0, 376.0, 9.0],
#        [3, 'Business', 26, ..., 14.0, 1046.0, 9.0]], dtype=object)

# %%
X_test = test_set.iloc[:,:].values
X_test
# Out:
# array([[3, 'Business', 27, ..., 19.0, 823.0, 6.0],
#        [3, 'Business', 17, ..., 102.0, 310.0, 3.0],
#        [3, 'Business', 27, ..., 1011.0, 1474.0, 4.0],
#        ...,
#        [3, 'Business', 5, ..., 24.0, 457.0, 5.0],
#        [3, 'Personal', 29, ..., 79.0, 348.0, 16.0],
#        [3, 'Business', 4, ..., 391.0, 398.0, 7.0]], dtype=object)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(drop='first'), [0,1])], remainder = 'passthrough')
X_train = np.array(ct.fit_transform(X_train))

#ct = ColumnTransformer(transformers = [('encoder', OneHotEncoder(drop='first'), [0,1])], remainder = 'passthrough')
X_test = np.array(ct.transform(X_test))

# %%
X_train.shape
# Out:
# (21201, 14)

# %%
X_test.shape
# Out:
# (7068, 14)

# %% [markdown]
# ## Feature Scaling

# %%
print(X_train)
print(X_test)
# Out:
# [[0.0 1.0 0.0 ... 264.0 1363.0 2.0]
#  [0.0 1.0 0.0 ... 425.0 227.0 11.0]
#  [0.0 1.0 0.0 ... 199.0 209.0 2.0]
#  ...
#  [0.0 1.0 0.0 ... 53.0 1235.0 11.0]
#  [0.0 0.0 0.0 ... 14.0 376.0 9.0]
#  [0.0 1.0 0.0 ... 14.0 1046.0 9.0]]
# [[0.0 1.0 0.0 ... 19.0 823.0 6.0]
#  [0.0 1.0 0.0 ... 102.0 310.0 3.0]
#  [0.0 1.0 0.0 ... 1011.0 1474.0 4.0]
#  ...
#  [0.0 1.0 0.0 ... 24.0 457.0 5.0]
#  [0.0 1.0 0.0 ... 79.0 348.0 16.0]
#  [0.0 1.0 0.0 ... 391.0 398.0 7.0]]

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.fit_transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.22014647  0.41750497 -0.03072853 ... -0.16498799  0.81294625
#   -1.01525517]
#  [-0.22014647  0.41750497 -0.03072853 ... -0.00802474 -0.67943684
#    1.00310118]
#  [-0.22014647  0.41750497 -0.03072853 ... -0.22835824 -0.70308375
#   -1.01525517]
#  ...
#  [-0.22014647  0.41750497 -0.03072853 ... -0.37069759  0.64479041
#    1.00310118]
#  [-0.22014647 -2.39518105 -0.03072853 ... -0.40871974 -0.48369293
#    0.55457754]
#  [-0.22014647  0.41750497 -0.03072853 ... -0.40871974  0.3964978
#    0.55457754]]

# %%
print(X_test)
# Out:
# [[-0.22340742  0.41840452 -0.0291482  ... -0.40906732  0.11768049
#   -0.11291473]
#  [-0.22340742  0.41840452 -0.0291482  ... -0.32680802 -0.57059627
#   -0.79367783]
#  [-0.22340742  0.41840452 -0.0291482  ...  0.57408008  0.99110771
#   -0.5667568 ]
#  ...
#  [-0.22340742  0.41840452 -0.0291482  ... -0.40411194 -0.37337076
#   -0.33983576]
#  [-0.22340742  0.41840452 -0.0291482  ... -0.34960276 -0.5196128
#    2.15629562]
#  [-0.22340742  0.41840452 -0.0291482  ... -0.04038705 -0.4525293
#    0.11400631]]

# %% [markdown]
# ## Multiple Linear Model

# %%
from sklearn.linear_model import LinearRegression
multiple_linear = LinearRegression()
multiple_linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = multiple_linear.predict(X_train)
y_pred
# Out:
# array([ 853.01904751, 2438.74390783, 1027.98928491, ..., 2524.55885645,
#        1925.59573257, 1818.52270808])

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_train,y_pred)))
# Out:
# 786.0372744352252

# %%
final_y=multiple_linear.predict(X_test)

# %% [markdown]
# ## Support Vector Regression Model

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel = 'rbf')
svr_model.fit(X_train,y_train)

# %%
y_pred1 = svr_model.predict(X_train)
y_pred1

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_train,y_pred1)))

# %%
final_y1=svr_model.predict(X_test)

# %% [markdown]
# ## Polynomial Regression Model

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y_train)

# %%
y_pred2 =lin_reg.predict(X_train)
y_pred2

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_train,y_pred2)))

# %%
final_y2=lin_reg.predict(X_test)

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
dt_model = DecisionTreeRegressor(random_state = 0)
dt_model.fit(X_train, y_train)

# %%
y_pred3 =dt_model.predict(X_train)
y_pred3

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_train,y_pred3)))

# %%
final_y3=dt_model.predict(X_test)

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators = 10, random_state = 0)
rf_model.fit(X_train, y_train)

# %%
y_pred4 = rf_model.predict(X_train)
y_pred4

# %%
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_train,y_pred4)))

# %%
final_y4=rf_model.predict(X_test)

# %%
submission_df = test_copy[['Order No']]
submission_df['Time from Pickup to Arrival'] =final_y
# Out:
# <ipython-input-69-5e7baf1fa286>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission_df['Time from Pickup to Arrival'] =final_y

# %%
#submission_df.to_csv(r'C:\Users\venetia mokgawa\Downloads\Sendy dataset\Random2_model.csv',index=False)

# %% [markdown]
# ## **MODEL #1**

# %% [markdown]
# ## **MODEL #2**

# %% [markdown]
# ## **MODEL #3**
